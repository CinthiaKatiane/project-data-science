# %% [markdown]
# # Ciência de Dados
#
# ### Grupo: Ailton Santos, Allan Gonçalves, Cinthia Katiane, Welligton Miguel

# %% [markdown]
# Esse notebook faz análise dos dados do cenário político brasileiro, e tem como fonte de informação os dados abertos da câmara, disponível em https://dadosabertos.camara.leg.br. Os datasets utilizados aqui foram tratados e concatenados previamente para atender requisitos do trabalho, mas o script para isso está disponível no repo do GitHub. Para mais informações leia o README do projeto.
#
# TEMPO ESTIMADO DE RESOLUÇÃO: ***20min***

# %% [markdown]
# ## 0. Introdução
#
# O ano de 2018 é um ano de eleições no Brasil e os eleitores podem usar muitas alternativas para escolher em quem vão votar, uma dessas alternativas é verificar a produtividade de um determinado político. Então é isso que vamos fazer nesse notebook. O primeiro passo é fazer o upload dos arquivos `proposicoes.csv`,`autores.csv` e `deputados.csv`, pois vamos usa-los em breve.

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %% [markdown]
# ## 1. Primeiros Passos
# #### Fácil
# Começe importando a biblioteca pandas e lendo o arquivo `proposicoes.csv`. Faça isso usando a função `read_csv()` com o ***nome do arquivo*** e o ***ponto e vírgula*** como `separador`. Atribua o DataFrame a variável __df_proposicoes__. Em seguida liste as colunas desse dataframe.
#
# Em uma célula diferente, execute a função `head()`. Tal função permitirá que você veja uma amostra dos dados desse dataframe. Dê uma olhada nas informações de cada coluna e então vá para o próximo exercício.

# %%
# Coloque seu codigo aqui

# %% [markdown]
# ## 2. Formatando Colunas
# #### Médio
#
# Sabemos que um dos pontos fundamentais para que seja possível efetuar uma boa análise é o tratamento dos dados, desta forma, iremos padronizar as colunas em nosso dataset. Vemos que ele segue uma mistura nos parões CamelCase e snake_case, sendo assim, iremos torná-lo apenas snake_case.
#
# Desta forma deve ser realizado:
#
# 1. Conversão de todas as colunas que se encontram no estilo camelCase para snake_case.
#
# 2. Remover das colunas o nome `ultimo_status_`.

# %%
# Coloque seu codigo aqui

# %% [markdown]
# ## 3. Removendo colunas desnecessárias
# #### Fácil
#
# Esse dataset possui muitas colunas, muitas mesmo, e boa parte delas não será útil para a nossa análise. Remova as seguintes colunas do dataframe:
#
# `'id_tipo',
#  'id_orgao',
#  'sigla_orgao',
#  'uri_orgao',
#  'descricao_tramitacao',
#  'id_tipo_tramitacao',
#  'id_situacao',
#  'data_apresentacao',
#  'uri_prop_posterior',
#  'url_inteiro_teor',
#  'urn_final',
#  'sequencia',
#  'uri_relator',
#  'uri_prop_principal',
#  'uri_prop_anterior',
#  'uri_orgao_numerador',
#  'uri'`
#
# Dica: Você pode usar a função [`drop()`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html) no Dataframe, passando essas colunas como parametro.
#
# Em seguida use a função `head()` novamente e veja como ficou o dataframe.

# %%
## Coloque seu código aqui

# %% [markdown]
# ## Métricas de Análise
#
# Agora que já efetuamos a padronização de colunas, onde possuimos apenas as informações necessárias para nossa análise, iremos partir para as estratégias, ou métricas(se preferir).
#
# Com elas iremos ter um alvo a atingir, seja qual deputado possui mais proposições até quantas proposições estão com situação "prontas para pauta".
#
# Sendo assim, hora de partir para a coleta...

# %% [markdown]
# ## 4. Métricas Quantitativas
# #### Médio
#
# Atualmente carregamos o csv contendo todas as proposições entre 2015 à 2018, desta forma faremos a seguinte análise:
#
# 1. Identificar todas as proposições do tipo PL e adicionar a variável `pl_proposicoes`
# 2. Após efetuada a separação das proposições do tipo PL, deveremos efetuar uma contagem de quantas PL foram realizadas em seus respectivos anos, com isso, deveremos adicionar o resultado a um dicionário `dict_pl_propocicoes_anos` onde o ano será a chave e a quantidade o valor

# %%
# Coloque seu codigo aqui

# %% [markdown]
# ## 5. Descobrindo os autores pt.1
# #### Fácil
#
# Agora que temos o dataframe com os projetos de lei, vamos descobrir quais foram os autores desses projetos. Para isso vamos:
#
# 1. Ler o arquivo `autores.csv` com `sep=;` e atribuir a variável __df_autores__
#
# Na nossa análise, desejamos analisar apenas os deputados. Sendo assim, realize essa extração da seguinte forma:
#
# 2. Selecione apenas as linhas onde o `cod_tipo_autor` é igual a 10000 (código para deputados)
#
# Perceba que após realizar essa filtragem, as colunas ***cod_tipo_autor*** e ***tipo_autor*** tornaram-se desnecessária, pois só existe um único valor nelas.
#
# 3. Remova as colunas `cod_tipo_autor` e `tipo_autor`

# %%
## Digite seu código aqui

# %% [markdown]
# ## 6. Descobrindo os autores pt.2
# #### IZI
#
# O dataframe de autores não possui muitos detalhes sobre os deputados, então precisaremos encontrar essas informações em outro lugar.
#
# 1. Leia o arquivo `deputados.csv` com `sep=;` e atribua a variável __df_deputados__
# 2. Selecione apenas as colunas `'uri', 'nome_civil', 'sigla_sexo', 'data_nascimento', 'uf_nascimento'`

# %%
## Digite seu código aqui

# %% [markdown]
# **Continuando**: Agora que você fez isso, execute a célula seguinte onde fizemos a junção dos dataframes de autores e deputados usando a função `merge()`.
#
# Para realizar um _merge_ é necessário que exista uma coluna em ambos os dataframes que possam "se relacionar". A partir disso, especifique quais são as colunas com os seguintes atributos:
# 1. `left_on` para a coluna do primeiro dataframe
# 2. `right_on` para a coluna do segundo dataframe
# 3. Para especificar o formato de junção: `how`. As opções são `outer`, onde todas linhas são combinadas sem que haja um "match". `inner` para "matches" perfeitos, `left` para manter todas as chaves do primeiro dataframe e atribuir Null quando não existe dado. Por fim `right` para manter todas as chaves do segundo dataframe, atribuindo null para os valores inexistentes no primeiro dataframe.

# %%
df_autor_deputado = pd.merge(df_autores, df_deputados, left_on='uri_autor', right_on='uri', how='left')
df_autor_deputado = df_autor_deputado.drop(['uri_autor', 'uri'], axis=1)
df_autor_deputado
# Out:
#         id_proposicao                                     uri_proposicao  \
# 0             2110932  https://dadosabertos.camara.leg.br/api/v2/prop...
# 1             2081753  https://dadosabertos.camara.leg.br/api/v2/prop...
# 2             2076239  https://dadosabertos.camara.leg.br/api/v2/prop...
# 3             2076210  https://dadosabertos.camara.leg.br/api/v2/prop...
# 4             2076209  https://dadosabertos.camara.leg.br/api/v2/prop...
# 5             2076208  https://dadosabertos.camara.leg.br/api/v2/prop...
# 6             2076207  https://dadosabertos.camara.leg.br/api/v2/prop...
# 7             2076207  https://dadosabertos.camara.leg.br/api/v2/prop...
# 8             2076206  https://dadosabertos.camara.leg.br/api/v2/prop...
# 9             2076205  https://dadosabertos.camara.leg.br/api/v2/prop...
# 10            2076204  https://dadosabertos.camara.leg.br/api/v2/prop...
# 11            2076203  https://dadosabertos.camara.leg.br/api/v2/prop...
# 12            2076202  https://dadosabertos.camara.leg.br/api/v2/prop...
# 13            2076201  https://dadosabertos.camara.leg.br/api/v2/prop...
# 14            2076200  https://dadosabertos.camara.leg.br/api/v2/prop...
# 15            2076199  https://dadosabertos.camara.leg.br/api/v2/prop...
# 16            2076198  https://dadosabertos.camara.leg.br/api/v2/prop...
# 17            2076197  https://dadosabertos.camara.leg.br/api/v2/prop...
# 18            2076196  https://dadosabertos.camara.leg.br/api/v2/prop...
# 19            2076195  https://dadosabertos.camara.leg.br/api/v2/prop...
# 20            2076194  https://dadosabertos.camara.leg.br/api/v2/prop...
# 21            2076193  https://dadosabertos.camara.leg.br/api/v2/prop...
# 22            2076192  https://dadosabertos.camara.leg.br/api/v2/prop...
# 23            2076191  https://dadosabertos.camara.leg.br/api/v2/prop...
# 24            2076190  https://dadosabertos.camara.leg.br/api/v2/prop...
# 25            2076189  https://dadosabertos.camara.leg.br/api/v2/prop...
# 26            2076188  https://dadosabertos.camara.leg.br/api/v2/prop...
# 27            2076187  https://dadosabertos.camara.leg.br/api/v2/prop...
# 28            2076186  https://dadosabertos.camara.leg.br/api/v2/prop...
# 29            2076185  https://dadosabertos.camara.leg.br/api/v2/prop...
# ...               ...                                                ...
# 121278        2167625  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121279        2167624  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121280        2167623  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121281        2167622  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121282        2167621  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121283        2167620  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121284        2167619  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121285        2167618  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121286        2167617  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121287        2167616  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121288        2167615  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121289        2167614  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121290        2167613  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121291        2167612  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121292        2167611  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121293        2167610  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121294        2167609  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121295        2167608  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121296        2167607  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121297        2167606  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121298        2167605  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121299        2167604  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121300        2167603  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121301        2167584  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121302        2167581  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121303        2167567  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121304        2167566  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121305        2167565  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121306        2167563  https://dadosabertos.camara.leg.br/api/v2/prop...
# 121307        2167558  https://dadosabertos.camara.leg.br/api/v2/prop...
#
#         id_autor  cod_tipo_autor tipo_autor                   nome_autor  \
# 0        73788.0           10000   Deputado               Ricardo Barros
# 1       178875.0           10000   Deputado              Alexandre Baldy
# 2       178933.0           10000   Deputado                 Sergio Souza
# 3       178976.0           10000   Deputado                  Bruno Covas
# 4       178976.0           10000   Deputado                  Bruno Covas
# 5       178976.0           10000   Deputado                  Bruno Covas
# 6       152605.0           10000   Deputado                Glauber Braga
# 7        74585.0           10000   Deputado              Lincoln Portela
# 8       178932.0           10000   Deputado             Marcelo Belinati
# 9       178932.0           10000   Deputado             Marcelo Belinati
# 10      178932.0           10000   Deputado             Marcelo Belinati
# 11      178932.0           10000   Deputado             Marcelo Belinati
# 12      178932.0           10000   Deputado             Marcelo Belinati
# 13      178932.0           10000   Deputado             Marcelo Belinati
# 14      178932.0           10000   Deputado             Marcelo Belinati
# 15      178932.0           10000   Deputado             Marcelo Belinati
# 16      178932.0           10000   Deputado             Marcelo Belinati
# 17      178932.0           10000   Deputado             Marcelo Belinati
# 18      178932.0           10000   Deputado             Marcelo Belinati
# 19      178932.0           10000   Deputado             Marcelo Belinati
# 20      178932.0           10000   Deputado             Marcelo Belinati
# 21      178932.0           10000   Deputado             Marcelo Belinati
# 22      178932.0           10000   Deputado             Marcelo Belinati
# 23      178932.0           10000   Deputado             Marcelo Belinati
# 24      178932.0           10000   Deputado             Marcelo Belinati
# 25      178932.0           10000   Deputado             Marcelo Belinati
# 26      178932.0           10000   Deputado             Marcelo Belinati
# 27      178932.0           10000   Deputado             Marcelo Belinati
# 28      178932.0           10000   Deputado             Marcelo Belinati
# 29      178932.0           10000   Deputado             Marcelo Belinati
# ...          ...             ...        ...                          ...
# 121278  141536.0           10000   Deputado               Rômulo Gouveia
# 121279  141536.0           10000   Deputado               Rômulo Gouveia
# 121280  141536.0           10000   Deputado               Rômulo Gouveia
# 121281  141536.0           10000   Deputado               Rômulo Gouveia
# 121282  141536.0           10000   Deputado               Rômulo Gouveia
# 121283  141536.0           10000   Deputado               Rômulo Gouveia
# 121284  141536.0           10000   Deputado               Rômulo Gouveia
# 121285  178825.0           10000   Deputado                 Leo de Brito
# 121286  160511.0           10000   Deputado             Alessandro Molon
# 121287  160511.0           10000   Deputado             Alessandro Molon
# 121288  160511.0           10000   Deputado             Alessandro Molon
# 121289  160511.0           10000   Deputado             Alessandro Molon
# 121290  160511.0           10000   Deputado             Alessandro Molon
# 121291  160511.0           10000   Deputado             Alessandro Molon
# 121292  160511.0           10000   Deputado             Alessandro Molon
# 121293   76287.0           10000   Deputado                Marcelo Matos
# 121294  178884.0           10000   Deputado                  Hildo Rocha
# 121295  178884.0           10000   Deputado                  Hildo Rocha
# 121296  178884.0           10000   Deputado                  Hildo Rocha
# 121297  178884.0           10000   Deputado                  Hildo Rocha
# 121298  178884.0           10000   Deputado                  Hildo Rocha
# 121299  178981.0           10000   Deputado             Herculano Passos
# 121300  141472.0           10000   Deputado              Ricardo Tripoli
# 121301  178959.0           10000   Deputado              Hiran Gonçalves
# 121302  160565.0           10000   Deputado                Mara Gabrilli
# 121303   73584.0           10000   Deputado  Antonio Carlos Mendes Thame
# 121304  160602.0           10000   Deputado                Arnaldo Jordy
# 121305  160602.0           10000   Deputado                Arnaldo Jordy
# 121306   74161.0           10000   Deputado              Reginaldo Lopes
# 121307   73466.0           10000   Deputado                 Rubens Bueno
#
#        sigla_partido_autor                                  uri_partido_autor  \
# 0                      NaN                                                NaN
# 1                      PTN  https://dadosabertos.camara.leg.br/api/v2/part...
# 2                     PMDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 3                     PSDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 4                     PSDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 5                     PSDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 6                     PSOL  https://dadosabertos.camara.leg.br/api/v2/part...
# 7                      PRB  https://dadosabertos.camara.leg.br/api/v2/part...
# 8                       PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 9                       PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 10                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 11                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 12                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 13                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 14                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 15                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 16                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 17                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 18                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 19                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 20                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 21                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 22                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 23                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 24                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 25                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 26                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 27                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 28                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 29                      PP  https://dadosabertos.camara.leg.br/api/v2/part...
# ...                    ...                                                ...
# 121278                 PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 121279                 PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 121280                 PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 121281                 PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 121282                 PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 121283                 PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 121284                 PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 121285                  PT  https://dadosabertos.camara.leg.br/api/v2/part...
# 121286                REDE  https://dadosabertos.camara.leg.br/api/v2/part...
# 121287                REDE  https://dadosabertos.camara.leg.br/api/v2/part...
# 121288                REDE  https://dadosabertos.camara.leg.br/api/v2/part...
# 121289                REDE  https://dadosabertos.camara.leg.br/api/v2/part...
# 121290                REDE  https://dadosabertos.camara.leg.br/api/v2/part...
# 121291                REDE  https://dadosabertos.camara.leg.br/api/v2/part...
# 121292                REDE  https://dadosabertos.camara.leg.br/api/v2/part...
# 121293                 PHS  https://dadosabertos.camara.leg.br/api/v2/part...
# 121294                PMDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 121295                PMDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 121296                PMDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 121297                PMDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 121298                PMDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 121299                 PSD  https://dadosabertos.camara.leg.br/api/v2/part...
# 121300                PSDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 121301                  PP  https://dadosabertos.camara.leg.br/api/v2/part...
# 121302                PSDB  https://dadosabertos.camara.leg.br/api/v2/part...
# 121303                  PV  https://dadosabertos.camara.leg.br/api/v2/part...
# 121304                 PPS  https://dadosabertos.camara.leg.br/api/v2/part...
# 121305                 PPS  https://dadosabertos.camara.leg.br/api/v2/part...
# 121306                  PT  https://dadosabertos.camara.leg.br/api/v2/part...
# 121307                 PPS  https://dadosabertos.camara.leg.br/api/v2/part...
#
#        sigla_uf_autor                          nome_civil sigla_sexo  \
# 0                 NaN       RICARDO JOSÉ MAGALHÃES BARROS          M
# 1                  GO  ALEXANDRE BALDY DE SANT'ANNA BRAGA          M
# 2                  PR                     SERGIO DE SOUZA          M
# 3                  SP                   BRUNO COVAS LOPES          M
# 4                  SP                   BRUNO COVAS LOPES          M
# 5                  SP                   BRUNO COVAS LOPES          M
# 6                  RJ           GLAUBER DE MEDEIROS BRAGA          M
# 7                  MG               LINCOLN DINIZ PORTELA          M
# 8                  PR            MARCELO BELINATI MARTINS          M
# 9                  PR            MARCELO BELINATI MARTINS          M
# 10                 PR            MARCELO BELINATI MARTINS          M
# 11                 PR            MARCELO BELINATI MARTINS          M
# 12                 PR            MARCELO BELINATI MARTINS          M
# 13                 PR            MARCELO BELINATI MARTINS          M
# 14                 PR            MARCELO BELINATI MARTINS          M
# 15                 PR            MARCELO BELINATI MARTINS          M
# 16                 PR            MARCELO BELINATI MARTINS          M
# 17                 PR            MARCELO BELINATI MARTINS          M
# 18                 PR            MARCELO BELINATI MARTINS          M
# 19                 PR            MARCELO BELINATI MARTINS          M
# 20                 PR            MARCELO BELINATI MARTINS          M
# 21                 PR            MARCELO BELINATI MARTINS          M
# 22                 PR            MARCELO BELINATI MARTINS          M
# 23                 PR            MARCELO BELINATI MARTINS          M
# 24                 PR            MARCELO BELINATI MARTINS          M
# 25                 PR            MARCELO BELINATI MARTINS          M
# 26                 PR            MARCELO BELINATI MARTINS          M
# 27                 PR            MARCELO BELINATI MARTINS          M
# 28                 PR            MARCELO BELINATI MARTINS          M
# 29                 PR            MARCELO BELINATI MARTINS          M
# ...               ...                                 ...        ...
# 121278             PB              RÔMULO JOSÉ DE GOUVEIA          M
# 121279             PB              RÔMULO JOSÉ DE GOUVEIA          M
# 121280             PB              RÔMULO JOSÉ DE GOUVEIA          M
# 121281             PB              RÔMULO JOSÉ DE GOUVEIA          M
# 121282             PB              RÔMULO JOSÉ DE GOUVEIA          M
# 121283             PB              RÔMULO JOSÉ DE GOUVEIA          M
# 121284             PB              RÔMULO JOSÉ DE GOUVEIA          M
# 121285             AC             LEONARDO CUNHA DE BRITO          M
# 121286             RJ           ALESSANDRO LUCCIOLA MOLON          M
# 121287             RJ           ALESSANDRO LUCCIOLA MOLON          M
# 121288             RJ           ALESSANDRO LUCCIOLA MOLON          M
# 121289             RJ           ALESSANDRO LUCCIOLA MOLON          M
# 121290             RJ           ALESSANDRO LUCCIOLA MOLON          M
# 121291             RJ           ALESSANDRO LUCCIOLA MOLON          M
# 121292             RJ           ALESSANDRO LUCCIOLA MOLON          M
# 121293             RJ           MARCELO VIVIANI GONÇALVES          M
# 121294             MA         HILDO AUGUSTO DA ROCHA NETO          M
# 121295             MA         HILDO AUGUSTO DA ROCHA NETO          M
# 121296             MA         HILDO AUGUSTO DA ROCHA NETO          M
# 121297             MA         HILDO AUGUSTO DA ROCHA NETO          M
# 121298             MA         HILDO AUGUSTO DA ROCHA NETO          M
# 121299             SP    HERCULANO CASTILHO PASSOS JUNIOR          M
# 121300             SP      JOSÉ RICARDO ALVARENGA TRIPOLI          M
# 121301             RR     HIRAN MANUEL GONCALVES DA SILVA          M
# 121302             SP              MARA CRISTINA GABRILLI          F
# 121303             SP      ANTONIO CARLOS DE MENDES THAME          M
# 121304             PA            ARNALDO JORDY FIGUEIREDO          M
# 121305             PA            ARNALDO JORDY FIGUEIREDO          M
# 121306             MG  REGINALDO LÁZARO DE OLIVEIRA LOPES          M
# 121307             PR                        RUBENS BUENO          M
#
#        data_nascimento uf_nascimento
# 0           1959-11-15            PR
# 1           1980-07-21            GO
# 2           1971-03-13            PR
# 3           1980-04-07            SP
# 4           1980-04-07            SP
# 5           1980-04-07            SP
# 6           1982-06-26            RJ
# 7           1953-11-03            MG
# 8           1971-07-22            PR
# 9           1971-07-22            PR
# 10          1971-07-22            PR
# 11          1971-07-22            PR
# 12          1971-07-22            PR
# 13          1971-07-22            PR
# 14          1971-07-22            PR
# 15          1971-07-22            PR
# 16          1971-07-22            PR
# 17          1971-07-22            PR
# 18          1971-07-22            PR
# 19          1971-07-22            PR
# 20          1971-07-22            PR
# 21          1971-07-22            PR
# 22          1971-07-22            PR
# 23          1971-07-22            PR
# 24          1971-07-22            PR
# 25          1971-07-22            PR
# 26          1971-07-22            PR
# 27          1971-07-22            PR
# 28          1971-07-22            PR
# 29          1971-07-22            PR
# ...                ...           ...
# 121278      1965-03-19            PB
# 121279      1965-03-19            PB
# 121280      1965-03-19            PB
# 121281      1965-03-19            PB
# 121282      1965-03-19            PB
# 121283      1965-03-19            PB
# 121284      1965-03-19            PB
# 121285      1979-04-13            AC
# 121286      1971-10-28            MG
# 121287      1971-10-28            MG
# 121288      1971-10-28            MG
# 121289      1971-10-28            MG
# 121290      1971-10-28            MG
# 121291      1971-10-28            MG
# 121292      1971-10-28            MG
# 121293      1968-05-26            RJ
# 121294      1960-04-22            MA
# 121295      1960-04-22            MA
# 121296      1960-04-22            MA
# 121297      1960-04-22            MA
# 121298      1960-04-22            MA
# 121299      1956-08-04            SP
# 121300      1952-04-17            SP
# 121301      1957-06-19            AM
# 121302      1967-09-28            SP
# 121303      1946-06-13            SP
# 121304      1958-11-30            PA
# 121305      1958-11-30            PA
# 121306      1973-04-02            MG
# 121307      1948-05-23            PR
#
# [121308 rows x 13 columns]

# %% [markdown]
# ## 7. Encontrando deputados mais participativos

# %% [markdown]
# Utilize o `df_autor_deputado` para a seguinte questão.
#
# Liste os 5 deputados do sexo feminino que contém o maior número de proposições.
#
# **Desafio**: Fazer essa questão utilizando uma única linha.

# %%
## Digite seu código aqui.

# %% [markdown]
# ## 8. Listando propostas de um deputado

# %% [markdown]
# Chegou a hora do desafio final. Para resolver essa questão, é preciso que você tenha entendido bem como realizar união de dataframes.
#
# Una os dataframes de `df_proposicoes`  na coluna `id` e `df_autor_deputado` na coluna `id_proposicao`. O formato de união deve ser `how=inner`.
#
# Após realizar a união dos datasets, liste todas as proposições que tem como ***nome_autor*** o deputado **Tiririca**

# %%
## Digite seu código aqui.

# %% [markdown]
# ## Bônus
#
# Verifique os deputados do nosso estado.
#
# User `value_counts()` para verificar quantas vezes cada um deles aparece.

# %%
## Digite seu código aqui
